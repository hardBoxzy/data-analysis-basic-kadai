# %%
# numpyの読み込み
import numpy as np

A = np.array([[0, 1], [2, 3], [4, 5]])
B = np.array([[0, 1, 2, 3], [4, 5, 6, 7]])
dot_AB = np.dot(A, B)
print(dot_AB)
dot_AB.max()
# Out:
# [[ 4  5  6  7]
#  [12 17 22 27]
#  [20 29 38 47]]
# np.int64(47)
